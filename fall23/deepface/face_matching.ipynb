# %%
import os
import glob
from deepface import DeepFace
import pandas as pd

class FaceRecognition:
    def __init__(self, missing_dir=None, unknown_dir=None, output_path=None, num_images=None, threshold=None, model='VGG-Face', metric='euclidean_l2'):
        self.missing_dir = missing_dir
        self.unknown_dir = unknown_dir
        self.output_path = output_path
        self.num_images = num_images
        self.threshold = threshold
        self.model = model
        self.metric = metric
        self.metric_col = self.model + "_" + self.metric

    def detect_and_match_faces(self):
        image_paths = glob.glob(os.path.join(self.missing_dir, "*"))
        if self.num_images:
            image_paths = image_paths[:self.num_images]  # Selecting the specified number from the start

        results = []

        for path in image_paths:
            ext = os.path.splitext(path)[1].lower()
            if ext in [".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff"]:
                # Detect face from the image
                detected_img_objs = DeepFace.extract_faces(path, enforce_detection=False)
                
            if detected_img_objs:
                dfs_list = DeepFace.find(
                    img_path=path,
                    db_path=self.unknown_dir, 
                    model_name=self.model,
                    distance_metric=self.metric,
                    enforce_detection=False
                )

                dfs = dfs_list[0]  # Use the first DataFrame in the list

                # Filter based on threshold
                if self.threshold is not None:
                    dfs = dfs[dfs[self.metric_col] >= self.threshold]

                    
                    if not dfs.empty:
                        matched_filenames = ', '.join(dfs['identity'].tolist())
                        metric_values = ', '.join(map(str, dfs[self.metric_col].tolist()))

                        results.append({
                            'missing_filename': path,
                            'unknowns_matched_filenames': matched_filenames,
                            self.metric_col: metric_values
                        })

        # Convert results to a pandas DataFrame and save to CSV
        df = pd.DataFrame(results)
        df.to_csv(self.output_path, index=False)

# Input your parameters here
missing_dir = 'missing'
unknown_dir = 'unknown'
output_path = 'matches.csv'

# Ask the user for the number of images, if input is empty, set num_images to None
try:
    num_images = input("Enter the number of images to process from the missing directory (press Enter for all): ")
    num_images = int(num_images) if num_images.strip() else None
except ValueError:
    print("Invalid input. Processing all images.")
    num_images = None

# Ask the user for the threshold metric value, if input is empty, set threshold to None
try:
    threshold = input("Enter a threshold metric value (press Enter for no threshold): ")
    threshold = float(threshold) if threshold.strip() else None
except ValueError:
    print("Invalid input. No threshold will be applied.")
    threshold = None

fr = FaceRecognition(
    missing_dir=missing_dir,
    unknown_dir=unknown_dir,
    output_path=output_path,
    num_images=num_images,
    threshold=threshold
)
fr.detect_and_match_faces()
# Out:
# 2023-11-08 17:27:29.981864: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-11-08 17:27:30.821375: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-08 17:27:31.674425: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-08 17:27:31.674456: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-08 17:27:31.675421: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-08 17:27:32.204402: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-11-08 17:27:32.205585: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-08 17:27:44.614934: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Enter the number of images to process from the missing directory (press Enter for all):
# Enter a threshold metric value (press Enter for no threshold): 0.70
# Finding representations:   0%|          | 0/500 [00:00<?, ?it/s]2023-11-08 17:28:16.595534: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2211] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Finding representations: 100%|██████████| 500/500 [01:22<00:00,  6.09it/s]
# Representations stored in unknown/representations_vgg_face.pkl file.Please delete this file when you add new identities in your database.
# find function lasts  82.76113843917847  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.4695322513580322  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5108168125152588  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5826444625854492  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.49198055267333984  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.499194860458374  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5403695106506348  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.513145923614502  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.45041513442993164  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.49568915367126465  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5026335716247559  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5309169292449951  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.7308478355407715  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.49175477027893066  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5154004096984863  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.9540505409240723  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.4748396873474121  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.4835829734802246  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5347113609313965  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5290119647979736  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5381934642791748  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5049200057983398  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.4607410430908203  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5725641250610352  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5367345809936523  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5192859172821045  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.45875978469848633  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.4798719882965088  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.531134843826294  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5454037189483643  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.4973258972167969  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.503140926361084  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5507173538208008  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5756886005401611  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5127668380737305  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5169925689697266  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.4679534435272217  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.566767692565918  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.487058162689209  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5516927242279053  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5210583209991455  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5076816082000732  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5158672332763672  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5351579189300537  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5279505252838135  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5259160995483398  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5659396648406982  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5190436840057373  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.561147928237915  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5255522727966309  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5456109046936035  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.515505313873291  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5271739959716797  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5181617736816406  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5747601985931396  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5466172695159912  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5718605518341064  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5570945739746094  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5283019542694092  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5280606746673584  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.528282880783081  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5259060859680176  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5469048023223877  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5139212608337402  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.47919702529907227  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5720398426055908  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5359821319580078  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5352237224578857  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.45511841773986816  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5140159130096436  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.51607346534729  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5483365058898926  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5096673965454102  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.512017011642456  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5301501750946045  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5322961807250977  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.4615824222564697  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.49991273880004883  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.45891714096069336  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5567991733551025  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5048713684082031  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5391337871551514  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5136375427246094  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5406405925750732  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5429494380950928  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5547430515289307  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.537121057510376  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5462570190429688  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5224885940551758  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5297946929931641  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5358996391296387  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5295991897583008  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5737566947937012  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5203845500946045  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.4642932415008545  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5126450061798096  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5965182781219482  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.484325647354126  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5350046157836914  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.498150110244751  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5079412460327148  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5139832496643066  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5235650539398193  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5110797882080078  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.570183515548706  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5407571792602539  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5224642753601074  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5305569171905518  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.515432596206665  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.48841142654418945  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5112991333007812  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.524280309677124  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5117359161376953  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.508023738861084  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5436880588531494  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.529973030090332  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5831434726715088  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5560803413391113  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.522465705871582  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5119659900665283  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.551471471786499  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5248425006866455  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.564446210861206  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5082457065582275  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5024118423461914  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.4746263027191162  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# ...
# find function lasts  0.5128257274627686  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5448932647705078  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5056371688842773  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5487744808197021  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5521228313446045  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.4676780700683594  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5157337188720703  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5418393611907959  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.4841585159301758  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5351090431213379  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.4957423210144043  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.49188971519470215  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5081367492675781  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5124630928039551  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5760085582733154  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.533069372177124  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5606420040130615  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5370368957519531  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5106475353240967  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5745947360992432  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5368790626525879  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5203433036804199  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5203635692596436  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5057036876678467  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5385825634002686  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5110161304473877  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5781834125518799  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.49038124084472656  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5038793087005615  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.4722411632537842  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5448284149169922  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5200676918029785  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5693998336791992  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.4971938133239746  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5405759811401367  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5359525680541992  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5408380031585693  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.4590423107147217  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5305228233337402  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.573340654373169  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5217761993408203  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.4632294178009033  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5643694400787354  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5005919933319092  seconds
# WARNING: Representations for images in unknown folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  501  representations found in  representations_vgg_face.pkl
# find function lasts  0.5244154930114746  seconds

# %%
df  = pd.read_csv('matches.csv')

# %%
df.shape
# Out:
# (924, 3)

# %%
df.head()
# Out:
#                                     missing_filename  \
# 0  missing/3b2e7ddf-2962-4373-a4db-e69bb2a13d25_p...
# 1  missing/f4040b65-f45c-481d-a99e-2a74b35ead85_p...
# 2  missing/a3d8d747-c1e9-4ae8-8eb3-ebf7730269dc_p...
# 3  missing/fb1e5053-2db4-4ea7-b0b1-1143c1bbca0a_p...
# 4  missing/8616902c-f6a0-48fc-9a96-46bf5eee0296_p...
#
#                           unknowns_matched_filenames  \
# 0  unknown/b3847520-ba03-49e5-8e40-2614928ce1f2_p...
# 1  unknown/76a728a1-ab90-4cdf-a5a8-340aa152c019_p...
# 2  unknown/6caf5780-91ea-42ba-8e8a-5578590fc555_p...
# 3  unknown/9106086c-b42f-4834-b7b5-e2639fc0dde7_p...
# 4  unknown/44bbe7c0-7ee6-4e33-a95f-caf91b3364b7_p...
#
#                                VGG-Face_euclidean_l2
# 0  0.7557863798011122, 0.7605595433755769, 0.7651...
# 1  0.7000915109390708, 0.7582780542041, 0.7645399...
# 2  0.7019144337495806, 0.7026456854222365, 0.7045...
# 3  0.7032221468435598, 0.7047502575439974, 0.7051...
# 4  0.7967741241264791, 0.8035782240635472, 0.8043...
