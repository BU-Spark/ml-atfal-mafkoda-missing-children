# %%
import os
print(os.getenv("CUDA_VISIBLE_DEVICES"))
# Out:
# 1

# %%
import gradio as gr
from POC_PIPELINE_functions import inference
# Out:
# {'batch_size': 8,
#  'board_interval': 50,
#  'checkpoint_path': None,
#  'dataset_type': 'ffhq_frontalize',
#  'device': 'cuda:0',
#  'encoder_type': 'GradualStyleEncoder',
#  'exp_dir': '',
#  'id_lambda': 1.0,
#  'image_interval': 100,
#  'input_nc': 3,
#  'l2_lambda': 0.001,
#  'l2_lambda_crop': 0.01,
#  'label_nc': 0,
#  'learning_rate': 0.0001,
#  'lpips_lambda': 0.08,
#  'lpips_lambda_crop': 0.8,
#  'max_steps': 80000,
#  'optim_name': 'ranger',
#  'resize_factors': None,
#  'save_interval': 5000,
#  'start_from_latent_avg': True,
#  'stylegan_weights': '',
#  'test_batch_size': 8,
#  'test_workers': 2,
#  'train_decoder': False,
#  'val_interval': 2500,
#  'w_norm_lambda': 0.005,
#  'workers': 8}
# Loading pSp from checkpoint: /projectnb/sparkgrp/ml-atfal-mafkoda-grp/pixel2style2pixel/pretrained/psp_ffhq_frontalization.pt
# Model successfully loaded!
# ------------ Options -------------
# activation: lrelu
# batchSize: 1
# checkpoints_dir: ./checkpoints
# ...

# %%
def face_age(image,gender,enhance,align):
    return inference(image,gender=gender,enhance = enhance,align = align)

def face_recog(image):
    return face_recognition_match(image)

demo = gr.Interface(fn=face_age, inputs=["image",gr.Dropdown(
            ["male", "female"], label="gender"),'checkbox','checkbox'], outputs="gallery")

demo.launch(share=True)
# Out:
# IMPORTANT: You are using gradio version 3.9, however version 3.14.0 is available, please upgrade.
# --------
# Running on local URL:  http://127.0.0.1:7860
# Running on public URL: https://f57bc5523ef72cb0.gradio.app
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades (NEW!), check out Spaces: https://huggingface.co/spaces
# <div><iframe src="https://f57bc5523ef72cb0.gradio.app" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# (<gradio.routes.App at 0x2b3e26189910>,
#  'http://127.0.0.1:7860/',
#  'https://f57bc5523ef72cb0.gradio.app')
# created temporary directory /scratch/7252835.1.cds-gpu/tmpkbhd6ta_
# AgingDataLoader
# dataset [MulticlassUnalignedDataset] was created
# Generator(
#   (id_encoder): IdentityEncoder(
#     (encoder): Sequential(
#       (0): ReflectionPad2d((3, 3, 3, 3))
#       (1): EqualConv2d(
# ...
